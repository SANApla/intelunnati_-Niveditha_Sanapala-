# %% [markdown]
# # Smartphone Price Prediction

# %% [markdown]
# ~Niveditha Sanapala

# %% [markdown]
# # Introduction

# %% [markdown]
# The data contains information regarding features,specification, and  price range of 2000 Smartphones. In this Project, I am going to explore and analyse a dataset and try to predict optimum price ranges for a list of Smartphones in the Market

# %% [markdown]
# The data features are as follows

# %% [markdown]
# 1)price_range(TARGET VARIABLE)

# %% [markdown]
# 2)battery_power(mAh)

# %% [markdown]
# 3)Bluetooth(Has bluetooth or not)

# %% [markdown]
# 4)clock_speed(speed at which microprocessor executes instructions)

# %% [markdown]
# 5)dual_sim(has dual sim support or not)

# %% [markdown]
# 6)fc(Front camera mega pixels)

# %% [markdown]
# 7)four_g(Has 4G support or not)

# %% [markdown]
# 8)int_memory(Internal memory in GigaBytes)

# %% [markdown]
# 9)m_dep(Smartphone Depth in Cm)

# %% [markdown]
# 10)mobile_wt(Weight of SmartPhone)

# %% [markdown]
# 11)n_cores(Number of cores in the processor)

# %% [markdown]
# 12)pc(Primary Camera Megapixels)

# %% [markdown]
# 13)px_height(Pixel Resolution height)

# %% [markdown]
# 14)px_width(Pixel Resolution width)

# %% [markdown]
# 15)ram(RAM in MB)

# %% [markdown]
# 16)sc_h( screen height in cm)

# %% [markdown]
# 17)sc_w( screen width in cm)

# %% [markdown]
# 18)talk_time(Longest time after a single charge)

# %% [markdown]
# 19)three_g(3g or not)

# %% [markdown]
# 20)touch_screen(Has touch screen or not)

# %% [markdown]
# 21)wifi(Has wifi or not)

# %%
#The libraries which we are going to use

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir("C:\\Users\\Niveditha S\\OneDrive\\Desktop\\Intel_Project")

# %%
df=pd.read_csv('Smart_phone.csv')

# %%
df.head()
# Out:
#    battery_power  Bluetooth  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0            842          0          2.2         0   1       0           7
# 1           1021          1          0.5         1   0       1          53
# 2            563          1          0.5         1   2       1          41
# 3            615          1          2.5         0   0       0          10
# 4           1821          1          1.2         0  13       1          44
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.6        188        2  ...         20       756  2549     9     7
# 1    0.7        136        3  ...        905      1988  2631    17     3
# 2    0.9        145        5  ...       1263      1716  2603    11     2
# 3    0.8        131        6  ...       1216      1786  2769    16     8
# 4    0.6        141        2  ...       1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %% [raw]
# Price range is classified into 4 categories as:
# 1)0(Low cost)
# 2)1(Medium cost)
# 3)2(High cost)
# 4)3(Very High cost)

# %%
#Exploring the dataset
df.columns
# Out:
# Index(['battery_power', 'Bluetooth', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.describe()
# Out:
#        battery_power  Bluetooth  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# To learn more about the metadata, we write the following line

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   Bluetooth      2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
pd.isnull(df)
# Out:
#       battery_power  Bluetooth  clock_speed  dual_sim     fc  four_g  \
# 0             False      False        False     False  False   False
# 1             False      False        False     False  False   False
# 2             False      False        False     False  False   False
# 3             False      False        False     False  False   False
# 4             False      False        False     False  False   False
# ...             ...        ...          ...       ...    ...     ...
# 1995          False      False        False     False  False   False
# 1996          False      False        False     False  False   False
# 1997          False      False        False     False  False   False
# 1998          False      False        False     False  False   False
# 1999          False      False        False     False  False   False
#
#       int_memory  m_dep  mobile_wt  n_cores  ...  px_height  px_width    ram  \
# ...

# %%
pd.isnull(df).sum()
# Out:
# battery_power    0
# Bluetooth        0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# We do not have any Null values

# %% [markdown]
# To predict the relationship between the variables, we sketch the correlation matrix.Correlation matrix tells us how many pairs of variables are linearly related

# %%
plt.figure(figsize=(12,9))
sns.heatmap(df.corr(),cmap='magma')
# Out:
# <Axes: >

# %% [markdown]
# Let us determine how many 'low cost','medium cost','high cost','very high cost' phones are there with each discrete value of a paramter

# %% [markdown]
# # Check for Outliers

# %%
# Separate numerical and categorical features
num_cols=pd.DataFrame(df,columns=['battery_power','clock_speed','int_memory','m_dep','mobile_wt','n_cores','px_height','px_width','ram','sc_h','fc','sc_w','talk_time'])
cat_cols=pd.DataFrame(df,columns=['Bluetooth','dual_sim','four_g','three_g','touch_screen','wifi','price_range'])

# %%
# Separate numerical and categorical features into different lists
numerical_col=list(df.loc[:,['battery_power','clock_speed','int_memory','m_dep','mobile_wt','n_cores','px_height','px_width','ram','sc_h','fc','sc_w','talk_time']])
categorical_col=list(df.loc[:,['Bluetooth','dual_sim','four_g','three_g','touch_screen','wifi','price_range']])

# %%
sns.set_style('darkgrid')
def boxplots_custom(dataset, columns_list, rows, cols, suptitle):
    fig, axs = plt.subplots(rows, cols, sharey=True, figsize=(15,7))
    fig.suptitle(suptitle, y=1, size=25)
    axs = axs.flatten()
    for i, data in enumerate(columns_list):
        sns.boxplot(data=dataset[data], orient='h', palette='magma', ax=axs[i])
        axs[i].set_title(data + ', skewness is: '+str(round(dataset[data].skew(axis = 0, skipna = True), 2)))
        
boxplots_custom(dataset=df, columns_list=num_cols, rows=5, cols=3, suptitle='Boxplots for each variable')
plt.tight_layout()

# %% [markdown]
# # Detect Outliers

# %%
# Calculate the IQR for each column in the dataset
Q1 = num_cols.quantile(0.25)
Q3 = num_cols.quantile(0.75)
IQR = Q3 - Q1

# Identify outliers using the IQR method
outliers = ((num_cols < (Q1 - 1.5 * IQR)) | (num_cols > (Q3 + 1.5 * IQR)))

# Count the number of outliers for each variable
num_outliers = outliers.sum()

# Number of outliers for each variable
num_outliers.to_frame().T
# Out:
#    battery_power  clock_speed  int_memory  m_dep  mobile_wt  n_cores  \
# 0              0            0           0      0          0        0
#
#    px_height  px_width  ram  sc_h  fc  sc_w  talk_time
# 0          2         0    0     0  18     0          0

# %% [markdown]
# Boxplots indicate the presence of outliers in the fc and px_height features

# %% [markdown]
# # Distribution of Continuous and CategoricalData

# %%
TARGET = 'price_range'
FEATURES = [col for col in df.columns if col not in ['df', TARGET]]

cat_features = [col for col in FEATURES if df[col].nunique() < 25]
cont_features = [col for col in FEATURES if df[col].nunique() >= 25]

num_cat_features = len(cat_features)
num_cont_features = len(cont_features)

print(f"Total number of features except for the target: {len(FEATURES)}")
print(f"\033[92mNumber of categorical (<25 Unique Values) features: {num_cat_features}")
print(f"\033[96mNumber of continuous features: {num_cont_features}")

# Define labels and colors for the pie chart
labels = ['Categorical (<25 Unique Values)', 'Continuous']
colors = ['#bbddcb', '#cdddbb']

plt.pie([num_cat_features, num_cont_features], 
        labels=labels,
        colors=colors,
        textprops={'fontsize': 13},
        autopct='%1.1f%%')

# Add a title to the plot
plt.title('Distribution of Categorical and Continuous Features', fontsize=16)

# Show the plot
plt.show()
# Out:
# Total number of features except for the target: 20
# Number of categorical (<25 Unique Values) features: 13
# Number of continuous features: 7

# %% [markdown]
# # Exploring categorical Features

# %%
fig, axes = plt.subplots(7,2, figsize=(25,80))
sns.set_style('darkgrid')
idx = 0
for col in categorical_col:
    sns.countplot(data=df, y=col, palette='magma', orient='h',
                  ax=axes[idx][0]).set_title(f'Count of {col}', fontsize='25')
    for container in axes[idx][0].containers:
        axes[idx][0].bar_label(container)
    sns.countplot(data=df, y=col, palette='coolwarm', orient='h',  hue='price_range',
                  ax=axes[idx][1]).set_title(f'Count of {col} per Price range', fontsize='25')
    for container in axes[idx][1].containers:
        axes[idx][1].bar_label(container)
    idx +=1
plt.show()

# %% [markdown]
# # Exploring Numerical Features

# %%
fig, axes = plt.subplots(13,2, figsize=(20,80))
sns.set_style('darkgrid')
idx = 0
for col in (numerical_col):
    sns.kdeplot(data=df, x=col, palette='Greens',fill=True , hue='price_range', 
                ax=axes[idx][0]).set_title(f'Distribution of {col}', fontsize='16')
    sns.boxplot(data=df, x=col, palette='light:#5A9' , y='price_range', orient='h', 
                ax=axes[idx][1]).set_title(f'BoxPlot of {col}', fontsize='16')
    idx +=1
plt.show()

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('price_range',axis=1)
y=df['price_range']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %% [markdown]
# # Implementation of Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# C:\Users\Niveditha S\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions=lr.predict(X_test)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[114  28   2   0]
#  [ 23  81  32   5]
#  [  0  40  74  64]
#  [  0   1  30 106]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81       144
#            1       0.54      0.57      0.56       141
#            2       0.54      0.42      0.47       178
#            3       0.61      0.77      0.68       137
#
#     accuracy                           0.62       600
#    macro avg       0.63      0.64      0.63       600
# weighted avg       0.62      0.62      0.62       600

# %%
#CONCLUSION from Logistic Regression
accuracy_lr=62

# %% [markdown]
# # Implementation of Decision tree and Random Forest

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions=dtree.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       144
#            1       0.73      0.84      0.78       141
#            2       0.80      0.73      0.76       178
#            3       0.84      0.84      0.84       137
#
#     accuracy                           0.82       600
#    macro avg       0.82      0.82      0.82       600
# weighted avg       0.82      0.82      0.82       600

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[127  17   0   0]
#  [ 11 118  12   0]
#  [  0  26 130  22]
#  [  0   1  21 115]]

# %%
#CONCLUSION from Decision Tree
accuracy_dt=82

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=100)
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predictions=rfc.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93       144
#            1       0.77      0.85      0.81       141
#            2       0.88      0.76      0.82       178
#            3       0.90      0.93      0.92       137
#
#     accuracy                           0.87       600
#    macro avg       0.87      0.87      0.87       600
# weighted avg       0.87      0.87      0.87       600

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[136   8   0   0]
#  [ 11 120  10   0]
#  [  0  28 136  14]
#  [  0   0   9 128]]

# %%
#CONCLUSION from Random Forest
accuracy_rft=88

# %% [markdown]
# # K-Nearest Neighbors(KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
predictions=knn.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       144
#            1       0.86      0.89      0.87       141
#            2       0.89      0.85      0.87       178
#            3       0.92      0.91      0.92       137
#
#     accuracy                           0.90       600
#    macro avg       0.90      0.90      0.90       600
# weighted avg       0.90      0.90      0.90       600

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[139   5   0   0]
#  [ 10 125   6   0]
#  [  0  15 152  11]
#  [  0   0  12 125]]

# %% [markdown]
# Choosing a K Value

# %%
error_rate=[]
for i in range(1,40):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i=knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='red', linestyle='dashed', marker='o',
         markerfacecolor='black', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# Here,we can see that around k=16,k=17,k=19 and k=27 the error rate just tends to hover around 0.02-0.01

# %%
knn=KNeighborsClassifier(n_neighbors=16)
knn.fit(X_train,y_train)
k_pred=knn.predict(X_test)
print('WITH K= 16')

print(classification_report(y_test,k_pred))

print(confusion_matrix(y_test,k_pred))
# Out:
# WITH K= 16
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       144
#            1       0.88      0.94      0.91       141
#            2       0.92      0.90      0.91       178
#            3       0.98      0.91      0.95       137
#
#     accuracy                           0.93       600
#    macro avg       0.94      0.94      0.93       600
# weighted avg       0.93      0.93      0.93       600
#
# [[142   2   0   0]
#  [  6 133   2   0]
#  [  0  16 160   2]
#  [  0   0  12 125]]

# %%
knn=KNeighborsClassifier(n_neighbors=27)
knn.fit(X_train,y_train)
k_pred=knn.predict(X_test)
print('WITH K= 27')

print(classification_report(y_test,k_pred))

print(confusion_matrix(y_test,k_pred))
# Out:
# WITH K= 27
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       144
#            1       0.89      0.94      0.91       141
#            2       0.93      0.89      0.91       178
#            3       0.96      0.93      0.94       137
#
#     accuracy                           0.93       600
#    macro avg       0.93      0.94      0.93       600
# weighted avg       0.93      0.93      0.93       600
#
# [[141   3   0   0]
#  [  6 133   2   0]
#  [  0  14 159   5]
#  [  0   0  10 127]]

# %%
#CONCLUSION from KNN
accuracy_knn=93

# %% [markdown]
# # CONCLUSION

# %%
models = ['logistic regression', 'decision tree', 'random forest', 'knn']
acc_scores = [0.62, 0.82, 0.88, 0.93]

plt.bar(models, acc_scores, color=['darkblue', 'purple', 'green', 'red'])
plt.ylabel("accuracy")
plt.title("Which model is most accurate?")
plt.show()

# %% [raw]
# Hence, we can conclude by saying that KNN is best model for this dataset as it achieved highest accuracy(0.93)
# Now,lets run KNN model to predict target values on the test dataset

# %%
os.chdir('C:\\Users\\Niveditha S\\OneDrive\\Desktop\\Intel_Project')

# %%
df1=pd.read_csv('sp_test.csv')

# %%
df1.head()
# Out:
#    id  battery_power  Bluetooth  clock_speed  dual_sim  fc  four_g  \
# 0   1           1043          1          1.8         1  14       0
# 1   2            841          1          0.5         1   4       1
# 2   3           1807          1          2.8         0   1       0
# 3   4           1546          0          0.5         1  18       1
# 4   5           1434          0          1.4         0  11       1
#
#    int_memory  m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  \
# 0           5    0.1        193  ...  16        226      1412  3476    12
# 1          61    0.8        191  ...  12        746       857  3895     6
# 2          27    0.9        186  ...   4       1270      1366  2396    17
# 3          25    0.5         96  ...  20        295      1752  3893    10
# 4          49    0.5        108  ...  18        749       810  1773    15
#
#    sc_w  talk_time  three_g  touch_screen  wifi
# 0     7          2        0             1     0
# ...

# %%
df1=df1.drop('id',axis=1)

# %%
df1.head()
# Out:
#    battery_power  Bluetooth  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0           1043          1          1.8         1  14       0           5
# 1            841          1          0.5         1   4       1          61
# 2           1807          1          2.8         0   1       0          27
# 3           1546          0          0.5         1  18       1          25
# 4           1434          0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193        3  16        226      1412  3476    12     7
# 1    0.8        191        5  12        746       857  3895     6     0
# 2    0.9        186        3   4       1270      1366  2396    17    10
# 3    0.5         96        8  20        295      1752  3893    10     0
# 4    0.5        108        6  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# ...

# %%
pred_price=knn.predict(df1)

# %%
pred_price
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 2, 1, 3, 2, 1, 3,
#        1, 1, 3, 0, 2, 0, 2, 0, 2, 0, 3, 0, 0, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 1, 0, 3, 1, 2, 1, 0, 3, 0, 3, 1, 3, 1, 1, 3, 3, 2, 0, 1, 1, 1,
#        2, 3, 1, 2, 1, 2, 2, 3, 3, 0, 2, 0, 2, 3, 0, 3, 3, 0, 3, 0, 3, 1,
#        3, 0, 1, 2, 2, 1, 2, 2, 0, 2, 1, 2, 1, 0, 0, 3, 0, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 3, 3, 3, 1, 3, 0, 0, 3, 2, 1, 2, 0, 3, 2, 3, 1, 0, 2,
#        1, 1, 3, 1, 1, 0, 3, 2, 1, 3, 1, 2, 2, 3, 3, 3, 2, 3, 2, 3, 1, 0,
#        3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 1, 0, 3, 0, 0, 0, 1, 1, 0, 1,
#        0, 0, 1, 2, 1, 0, 0, 1, 1, 2, 2, 1, 0, 0, 0, 0, 0, 3, 1, 0, 2, 2,
#        3, 3, 1, 1, 3, 3, 3, 2, 2, 1, 1, 0, 1, 2, 0, 2, 3, 3, 0, 2, 0, 3,
#        2, 3, 3, 1, 0, 1, 0, 3, 0, 1, 0, 2, 2, 1, 2, 0, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 3, 3, 1, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 0, 3, 2, 1, 2,
#        3, 3, 3, 1, 0, 1, 2, 3, 1, 1, 3, 2, 0, 3, 0, 0, 2, 0, 0, 3, 2, 3,
# ...

# %%
df1['price_range']=pred_price

# %%
df1.head()
# Out:
#    battery_power  Bluetooth  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0           1043          1          1.8         1  14       0           5
# 1            841          1          0.5         1   4       1          61
# 2           1807          1          2.8         0   1       0          27
# 3           1546          0          0.5         1  18       1          25
# 4           1434          0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193        3  ...        226      1412  3476    12     7
# 1    0.8        191        5  ...        746       857  3895     6     0
# 2    0.9        186        3  ...       1270      1366  2396    17    10
# 3    0.5         96        8  ...        295      1752  3893    10     0
# 4    0.5        108        6  ...        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %% [markdown]
# I have predicted price ranges for Smartphones in our new dataset
